-- %%
------------------------------------
-- Create table exchange_rates
CREATE OR REPLACE TABLE `demo_academy`.`bronze`.`exchange_rates` (
    base STRING,
    data_base DATE,
    moeda STRING,
    valor DOUBLE,
    updated TIMESTAMP
)
USING DELTA
COMMENT "Exchange rates of the world";
------------------------------------
