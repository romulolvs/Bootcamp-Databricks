-- %%
---------------------------------------------
CREATE OR REPLACE TABLE `capgemini_academy`.`bronze`.`fifa_world_cup_all_matches`
    SELECT * EXCEPT (_rescued_data)
    FROM read_files(
        '/Volumes/capgemini_academy/landing/files/fifa/*.csv',
        format => 'csv',
        header => true,
        inferSchema => true
    );
---------------------------------------------
