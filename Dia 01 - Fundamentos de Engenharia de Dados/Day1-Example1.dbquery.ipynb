-- %%
------------------------------
SELECT *
FROM csv.`/Volumes/capgemini_academy/landing/files/movielens/links.csv`;
------------------------------
SELECT *
FROM read_files('/Volumes/capgemini_academy/landing/files/movielens/links.csv',
    format => 'csv',
    inferColumnTypes => True,
    header => True
);
------------------------------
SELECT *
FROM read_files('/Volumes/demo_academy/landing/files/e-commerce-sales-analytics/*.csv',
    format => 'csv',
    inferSchema => True,
    header => True
);
------------------------------
CREATE TABLE IF NOT EXISTS `demo_academy`.`bronze`.`ecommerce_sales` (
    order_id INT,
    order_date DATE,
    customer_id INT,
    product_category STRING,
    region STRING,
    quantity INT,
    unit_price DOUBLE,
    discount DOUBLE,
    payment_method STRING,
    delivery_days INT,
    customer_rating DOUBLE,
    revenue DOUBLE
)
USING DELTA;
------------------------------
