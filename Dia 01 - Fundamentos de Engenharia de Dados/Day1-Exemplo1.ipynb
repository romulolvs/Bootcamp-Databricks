# %%
# %sql
SELECT *
FROM
    read_files('/Volumes/capgemini_academy/landing/files/movielens/links.csv',
        format => 'csv',
        header => True,
        inferSchema => True,
        inferColumnTypes => True
    );

# %%
df = spark.read.csv(
    '/Volumes/capgemini_academy/landing/files/movielens/links.csv',
    header=True,
    inferSchema=True
)

display(df)
