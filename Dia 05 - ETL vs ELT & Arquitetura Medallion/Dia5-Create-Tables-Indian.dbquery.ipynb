-- %%
--------------------------------------------------
CREATE OR REPLACE TABLE `capgemini_academy`.`bronze`.`customers`
    SELECT * EXCEPT(_rescued_data), from_utc_timestamp(current_timestamp(), 'America/Sao_Paulo') AS updated
    FROM read_files('/Volumes/capgemini_academy/landing/files/indian/customers.csv',
        format => 'csv',
        inferColumnTypes => False,
        header => True
    );
--------------------------------------------------
CREATE OR REPLACE TABLE `capgemini_academy`.`bronze`.`products`
    SELECT * EXCEPT(_rescued_data), from_utc_timestamp(current_timestamp(), 'America/Sao_Paulo') AS updated
    FROM read_files('/Volumes/capgemini_academy/landing/files/indian/products.csv',
        format => 'csv',
        inferColumnTypes => False,
        header => True
    );
--------------------------------------------------
CREATE OR REPLACE TABLE `capgemini_academy`.`bronze`.`sales`
    SELECT * EXCEPT(_rescued_data), from_utc_timestamp(current_timestamp(), 'America/Sao_Paulo') AS updated
    FROM read_files('/Volumes/capgemini_academy/landing/files/indian/sales.csv',
        format => 'csv',
        inferColumnTypes => False,
        header => True
    );
--------------------------------------------------
SELECT * FROM `capgemini_academy`.`bronze`.`customers` LIMIT 10;

SELECT * FROM `capgemini_academy`.`bronze`.`products` LIMIT 10;

SELECT * FROM `capgemini_academy`.`bronze`.`sales` LIMIT 10;
--------------------------------------------------
SELECT COUNT(*) FROM `capgemini_academy`.`bronze`.`customers`;

SELECT COUNT(*) FROM `capgemini_academy`.`bronze`.`products`;

SELECT COUNT(*) FROM `capgemini_academy`.`bronze`.`sales`;
--------------------------------------------------
