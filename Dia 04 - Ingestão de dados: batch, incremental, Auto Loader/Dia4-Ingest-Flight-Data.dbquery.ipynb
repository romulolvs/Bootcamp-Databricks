-- %%
--------------------------------------------------
CREATE TABLE IF NOT EXISTS `capgemini_academy`.`bronze`.`flight_data`;

COPY INTO `capgemini_academy`.`bronze`.`flight_data`
FROM '/Volumes/capgemini_academy/landing/files/flight/'
FILEFORMAT = JSON
FORMAT_OPTIONS ('multiLine' = 'false')
COPY_OPTIONS ('mergeSchema' = 'true');
--------------------------------------------------
SELECT * FROM `capgemini_academy`.`bronze`.`flight_data`;
--------------------------------------------------
DESCRIBE HISTORY `capgemini_academy`.`bronze`.`flight_data`;
--------------------------------------------------
